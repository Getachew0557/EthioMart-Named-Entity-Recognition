# %%
import pandas as pd
import re

# %%
df = pd.read_csv('../data/modern_Data.csv')
df.head(10)
# Out:
#                            Channel Title       Channel Username    ID  \
# 0  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4573
# 1  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4572
# 2  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4571
# 3  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4570
# 4  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4569
# 5  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4568
# 6  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4567
# 7  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4566
# 8  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4565
# 9  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4564
#
#                                              Message  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 4                                                NaN
# 5  ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
#
#                         Date                             Media Path  \
# 0  2024-09-26 11:50:31+00:00                                    NaN
# 1  2024-09-26 11:50:31+00:00  photos\@modernshoppingcenter_4572.jpg
# 2  2024-09-26 11:50:31+00:00  photos\@modernshoppingcenter_4571.jpg
# 3  2024-09-26 11:50:31+00:00                                    NaN
# 4  2024-09-26 03:45:21+00:00  photos\@modernshoppingcenter_4569.jpg
# 5  2024-09-26 03:45:21+00:00  photos\@modernshoppingcenter_4568.jpg
# 6  2024-09-25 12:29:56+00:00  photos\@modernshoppingcenter_4567.jpg
# 7  2024-09-25 12:29:56+00:00  photos\@modernshoppingcenter_4566.jpg
# 8  2024-09-25 12:29:56+00:00  photos\@modernshoppingcenter_4565.jpg
# 9  2024-09-25 12:29:56+00:00  photos\@modernshoppingcenter_4564.jpg
#
#        Sender ID  Views  Forwards  Reply To Message ID  \
# 0 -1001649695480   3643         2                  NaN
# 1 -1001649695480   3635         2                  NaN
# 2 -1001649695480   3636         2                  NaN
# 3 -1001649695480   3636         2                  NaN
# 4 -1001649695480   5524         0                  NaN
# 5 -1001649695480   5522         0                  NaN
# 6 -1001649695480   7308        10                  NaN
# 7 -1001649695480   7314        10                  NaN
# 8 -1001649695480   7331        10                  NaN
# 9 -1001649695480   7252        11                  NaN
#
#                                            Reactions  Reply Count
# 0                                                NaN            0
# 1                                                NaN            0
# 2                                                NaN            0
# 3  [<telethon.tl.types.ReactionCount object at 0x...            0
# 4                                                NaN            0
# 5  [<telethon.tl.types.ReactionCount object at 0x...            0
# 6                                                NaN            0
# 7                                                NaN            0
# 8                                                NaN            0
# 9  [<telethon.tl.types.ReactionCount object at 0x...            0

# %%
df.isna().sum()
# Out:
# Channel Title             0
# Channel Username          0
# ID                        0
# Message                 700
# Date                      0
# Media Path              133
# Sender ID                 0
# Views                     0
# Forwards                  0
# Reply To Message ID    1075
# Reactions               699
# Reply Count               0
# dtype: int64

# %%
print("checking for NAN values in the message column")
nan_count = df["Message"].isnull().sum()
print(f"number of Nan Vales {nan_count}")
# Out:
# checking for NAN values in the message column
# number of Nan Vales 700

# %%
print("Checking for NAN values in the 'Message' column")

# Count the number of NaN values
nan_count = df["Message"].isnull().sum()
print(f"Number of NaN values: {nan_count}")

# Drop rows with NaN in the 'Message' column
df = df.dropna(subset=['Message'])  # Removed extra space

# Print the shape of the dataset after removing NaN values
print(f"Dataset shape after removing NaN values: {df.shape}")
# Out:
# Checking for NAN values in the 'Message' column
# Number of NaN values: 700
# Dataset shape after removing NaN values: (375, 12)

# %%
df.head()
# Out:
#                             Channel Title       Channel Username    ID  \
# 3   ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4570
# 5   ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4568
# 9   ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4564
# 14  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4559
# 17  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4552
#
#                                               Message  \
# 3   ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 5   ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 9   ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 14  ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 17  ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
#
#                          Date                             Media Path  \
# 3   2024-09-26 11:50:31+00:00                                    NaN
# 5   2024-09-26 03:45:21+00:00  photos\@modernshoppingcenter_4568.jpg
# 9   2024-09-25 12:29:56+00:00  photos\@modernshoppingcenter_4564.jpg
# 14  2024-09-25 08:34:27+00:00                                    NaN
# 17  2024-09-24 17:46:05+00:00  photos\@modernshoppingcenter_4552.jpg
#
#         Sender ID  Views  Forwards  Reply To Message ID  \
# 3  -1001649695480   3636         2                  NaN
# 5  -1001649695480   5522         0                  NaN
# 9  -1001649695480   7252        11                  NaN
# 14 -1001649695480   7082         7                  NaN
# 17 -1001649695480   7923         9                  NaN
#
#                                             Reactions  Reply Count
# 3   [<telethon.tl.types.ReactionCount object at 0x...            0
# 5   [<telethon.tl.types.ReactionCount object at 0x...            0
# 9   [<telethon.tl.types.ReactionCount object at 0x...            0
# 14  [<telethon.tl.types.ReactionCount object at 0x...            0
# 17  [<telethon.tl.types.ReactionCount object at 0x...            0

# %%
message_df = df['Message']
message_df
# Out:
# 3       ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 5       ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 9       ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 14      ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 17      ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
#                               ...
# 1064    ቴሌግራም 👉 t.me/modernshoppingcenter\n     "በአዲስ ...
# 1067    ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 1068    ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 1070    ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# 1073    ቴሌግራም👉t.me/modernshoppingcenter\n     "በአዲስ ነገ...
# Name: Message, Length: 375, dtype: object

# %% [markdown]
# #### remove telegram link and different emojo

# %%
import pandas as pd
import re

# Function to remove emojis, Telegram links, the word "ቴሌግራም", and the first \n
def clean_text(text):
    # Remove emojis using regex
    text = re.sub(r'[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U00002702-\U000027B0]+', '', text)
    # Remove Telegram links
    text = re.sub(r't\.me/\S+', '', text)
    # Remove the word "ቴሌግራም"
    text = re.sub(r'ቴሌግራም', '', text)
    # Remove leading newline characters and other unnecessary spaces
    text = text.lstrip()
    return text

# Apply the cleaning function to the 'Message' column
df['Message'] = df['Message'].apply(clean_text)

# Display the cleaned DataFrame
print(df['Message'])
# Out:
# 3       "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Sayona Sandwich G...
# 5       "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Saachi Electric K...
# 9       "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Single cup Coffe ...
# 14      "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n toilet seat cover...
# 17      "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n ስመ ገናናዉ Sanford e...
#                               ...
# 1064    "በአዲስ ነገር ሁሌም ቀዳሚዏች ነን"\n\n የተለያዩ ነገሮችን ለመፍጨት ...
# 1067    "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n የባኞ ቤት በር መረጋገጫ\n...
# 1068    "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n የቴምር፣የኩኪስ፣የቆሎ፣የከረ...
# 1070    "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n ኳሊቲ የቡና ረከቦት\n የጀ...
# 1073    "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Stainless steel p...
# Name: Message, Length: 375, dtype: object

# %%
df.head()
# Out:
#                             Channel Title       Channel Username    ID  \
# 3   ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4570
# 5   ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4568
# 9   ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4564
# 14  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4559
# 17  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4552
#
#                                               Message  \
# 3   "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Sayona Sandwich G...
# 5   "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Saachi Electric K...
# 9   "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Single cup Coffe ...
# 14  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n toilet seat cover...
# 17  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n ስመ ገናናዉ Sanford e...
#
#                          Date                             Media Path  \
# 3   2024-09-26 11:50:31+00:00                                    NaN
# 5   2024-09-26 03:45:21+00:00  photos\@modernshoppingcenter_4568.jpg
# 9   2024-09-25 12:29:56+00:00  photos\@modernshoppingcenter_4564.jpg
# 14  2024-09-25 08:34:27+00:00                                    NaN
# 17  2024-09-24 17:46:05+00:00  photos\@modernshoppingcenter_4552.jpg
#
#         Sender ID  Views  Forwards  Reply To Message ID  \
# 3  -1001649695480   3636         2                  NaN
# 5  -1001649695480   5522         0                  NaN
# 9  -1001649695480   7252        11                  NaN
# 14 -1001649695480   7082         7                  NaN
# 17 -1001649695480   7923         9                  NaN
#
#                                             Reactions  Reply Count
# 3   [<telethon.tl.types.ReactionCount object at 0x...            0
# 5   [<telethon.tl.types.ReactionCount object at 0x...            0
# 9   [<telethon.tl.types.ReactionCount object at 0x...            0
# 14  [<telethon.tl.types.ReactionCount object at 0x...            0
# 17  [<telethon.tl.types.ReactionCount object at 0x...            0

# %% [markdown]
# #### Remove different tags and contents on Reactions entity

# %%
import pandas as pd
import re

# Function to extract the number of reactions
def extract_reaction_count(reaction_str):
    # Check if the input is a string
    if isinstance(reaction_str, str):
        # Use regex to find all numbers in the string
        numbers = re.findall(r'\d+', reaction_str)
        # Return the count of reactions
        return len(numbers)
    else:
        # Return 0 if the input is not a string or is NaN
        return 0

# Apply the extraction function to the 'Reactions' column
df['Reactions'] = df['Reactions'].apply(extract_reaction_count)

# Display the updated DataFrame with the number of reactions
print(df['Reactions'])
# Out:
# 3        7
# 5        6
# 9        8
# 14       9
# 17      14
#         ..
# 1064    11
# 1067     8
# 1068    17
# 1070    15
# 1073     8
# Name: Reactions, Length: 375, dtype: int64

# %%
df.head()
# Out:
#                             Channel Title       Channel Username    ID  \
# 3   ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4570
# 5   ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4568
# 9   ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4564
# 14  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4559
# 17  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  4552
#
#                                               Message  \
# 3   "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Sayona Sandwich G...
# 5   "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Saachi Electric K...
# 9   "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Single cup Coffe ...
# 14  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n toilet seat cover...
# 17  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n ስመ ገናናዉ Sanford e...
#
#                          Date                             Media Path  \
# 3   2024-09-26 11:50:31+00:00                                    NaN
# 5   2024-09-26 03:45:21+00:00  photos\@modernshoppingcenter_4568.jpg
# 9   2024-09-25 12:29:56+00:00  photos\@modernshoppingcenter_4564.jpg
# 14  2024-09-25 08:34:27+00:00                                    NaN
# 17  2024-09-24 17:46:05+00:00  photos\@modernshoppingcenter_4552.jpg
#
#         Sender ID  Views  Forwards  Reply To Message ID  Reactions  \
# 3  -1001649695480   3636         2                  NaN          7
# 5  -1001649695480   5522         0                  NaN          6
# 9  -1001649695480   7252        11                  NaN          8
# 14 -1001649695480   7082         7                  NaN          9
# 17 -1001649695480   7923         9                  NaN         14
#
#     Reply Count
# 3             0
# 5             0
# 9             0
# 14            0
# 17            0

# %%
df['Reactions'].unique
# Out:
# <bound method Series.unique of 3        7
# 5        6
# 9        8
# 14       9
# 17      14
#         ..
# 1064    11
# 1067     8
# 1068    17
# 1070    15
# 1073     8
# Name: Reactions, Length: 375, dtype: int64>

# %%
df = df.to_csv('../data/clean_data.csv')

# %%
df = pd.read_csv('../data/clean_data.csv')
df
# Out:
#      Unnamed: 0                          Channel Title       Channel Username  \
# 0             3  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
# 1             5  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
# 2             9  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
# 3            14  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
# 4            17  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
# ..          ...                                    ...                    ...
# 370        1064  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
# 371        1067  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
# 372        1068  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
# 373        1070  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
# 374        1073  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter
#
#        ID                                            Message  \
# 0    4570  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Sayona Sandwich G...
# 1    4568  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Saachi Electric K...
# 2    4564  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Single cup Coffe ...
# 3    4559  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n toilet seat cover...
# 4    4552  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n ስመ ገናናዉ Sanford e...
# ..    ...                                                ...
# 370  3323  "በአዲስ ነገር ሁሌም ቀዳሚዏች ነን"\n\n የተለያዩ ነገሮችን ለመፍጨት ...
# 371  3320  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n የባኞ ቤት በር መረጋገጫ\n...
# 372  3319  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n የቴምር፣የኩኪስ፣የቆሎ፣የከረ...
# 373  3317  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n ኳሊቲ የቡና ረከቦት\n የጀ...
# 374  3314  "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን" \n\n Stainless steel p...
#
#                           Date                             Media Path  \
# 0    2024-09-26 11:50:31+00:00                                    NaN
# 1    2024-09-26 03:45:21+00:00  photos\@modernshoppingcenter_4568.jpg
# 2    2024-09-25 12:29:56+00:00  photos\@modernshoppingcenter_4564.jpg
# 3    2024-09-25 08:34:27+00:00                                    NaN
# 4    2024-09-24 17:46:05+00:00  photos\@modernshoppingcenter_4552.jpg
# ..                         ...                                    ...
# 370  2024-03-08 08:38:23+00:00  photos\@modernshoppingcenter_3323.jpg
# 371  2024-03-07 18:29:45+00:00  photos\@modernshoppingcenter_3320.jpg
# 372  2024-03-07 15:20:59+00:00  photos\@modernshoppingcenter_3319.jpg
# 373  2024-03-07 11:01:22+00:00  photos\@modernshoppingcenter_3317.jpg
# 374  2024-03-07 07:37:15+00:00  photos\@modernshoppingcenter_3314.jpg
#
#          Sender ID  Views  Forwards  Reply To Message ID  Reactions  \
# 0   -1001649695480   3636         2                  NaN          7
# 1   -1001649695480   5522         0                  NaN          6
# 2   -1001649695480   7252        11                  NaN          8
# 3   -1001649695480   7082         7                  NaN          9
# 4   -1001649695480   7923         9                  NaN         14
# ..             ...    ...       ...                  ...        ...
# 370 -1001649695480  26666        32                  NaN         11
# 371 -1001649695480  25187        76                  NaN          8
# 372 -1001649695480  26778        31                  NaN         17
# 373 -1001649695480  26358        57                  NaN         15
# 374 -1001649695480  25062        25                  NaN          8
#
#      Reply Count
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 370            0
# 371            0
# 372            0
# 373            0
# 374            0
#
# [375 rows x 13 columns]
